# %% [markdown]
# # FMI Tutorial - Example incubator using UniFMU with FMI3 and clocks (Jupyter Notebook Version)
# Authors: Santiago Gil, Cláudio Gomes, and Yon Vannommeslaeghe
# Contact: sgil@ece.au.dk

# %% [markdown]
# ## Installing/importing dependencies

# %% [markdown]
# First, the Python libraries needed for the example

# %%
# !pip3 install colorama coloredlogs FMPy matplotlib pandas protobuf==5.27.3 pyzmq toml
# Out:
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (0.4.6)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (15.0.1)
# Requirement already satisfied: FMPy in /usr/local/lib/python3.11/dist-packages (0.3.25)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: protobuf==5.27.3 in /usr/local/lib/python3.11/dist-packages (5.27.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (24.0.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs) (10.0)
# Requirement already satisfied: attrs>=24.2.0 in /usr/local/lib/python3.11/dist-packages (from FMPy) (25.3.0)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from FMPy) (3.1.6)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.11/dist-packages (from FMPy) (1.2.2)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from FMPy) (5.4.0)
# Requirement already satisfied: msgpack>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from FMPy) (1.1.1)
# Requirement already satisfied: nbformat>=5.10.4 in /usr/local/lib/python3.11/dist-packages (from FMPy) (5.10.4)
# Requirement already satisfied: numpy>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from FMPy) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.4->FMPy) (3.0.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.10.4->FMPy) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.10.4->FMPy) (4.24.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.10.4->FMPy) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.10.4->FMPy) (5.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.10.4->FMPy) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.10.4->FMPy) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat>=5.10.4->FMPy) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.10.4->FMPy) (4.3.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat>=5.10.4->FMPy) (4.14.1)

# %% [markdown]
# Now, we'll get the UniFMU binaries (for Linux)

# %%
# !wget https://github.com/INTO-CPS-Association/unifmu/releases/download/v0.12.0-beta/unifmu-x86_64-unknown-linux-gnu-0.12.0.zip
# Out:
# --2025-07-18 07:58:28--  https://github.com/INTO-CPS-Association/unifmu/releases/download/v0.12.0-beta/unifmu-x86_64-unknown-linux-gnu-0.12.0.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/309479733/1e629cb5-28c3-4f9b-9272-633a4fa3f181?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-18T08%3A56%3A43Z&rscd=attachment%3B+filename%3Dunifmu-x86_64-unknown-linux-gnu-0.12.0.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-18T07%3A56%3A13Z&ske=2025-07-18T08%3A56%3A43Z&sks=b&skv=2018-11-09&sig=9LK4OFg6dPJcq2qFv8G3qLnqRE2YQE0ZnQ8tiPuGh5s%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MjgyNTgwOCwibmJmIjoxNzUyODI1NTA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.JibA9KioEA890qGXqZSVc0opL-FjyKv2RdBSv-NfN_U&response-content-disposition=attachment%3B%20filename%3Dunifmu-x86_64-unknown-linux-gnu-0.12.0.zip&response-content-type=application%2Foctet-stream [following]
# --2025-07-18 07:58:28--  https://release-assets.githubusercontent.com/github-production-release-asset/309479733/1e629cb5-28c3-4f9b-9272-633a4fa3f181?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-07-18T08%3A56%3A43Z&rscd=attachment%3B+filename%3Dunifmu-x86_64-unknown-linux-gnu-0.12.0.zip&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-07-18T07%3A56%3A13Z&ske=2025-07-18T08%3A56%3A43Z&sks=b&skv=2018-11-09&sig=9LK4OFg6dPJcq2qFv8G3qLnqRE2YQE0ZnQ8tiPuGh5s%3D&jwt=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1MjgyNTgwOCwibmJmIjoxNzUyODI1NTA4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.JibA9KioEA890qGXqZSVc0opL-FjyKv2RdBSv-NfN_U&response-content-disposition=attachment%3B%20filename%3Dunifmu-x86_64-unknown-linux-gnu-0.12.0.zip&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6399073 (6.1M) [application/octet-stream]
# Saving to: ‘unifmu-x86_64-unknown-linux-gnu-0.12.0.zip’
#
# unifmu-x86_64-unkno 100%[===================>]   6.10M  --.-KB/s    in 0.02s
#
# 2025-07-18 07:58:28 (258 MB/s) - ‘unifmu-x86_64-unknown-linux-gnu-0.12.0.zip’ saved [6399073/6399073]

# %%
# !ls
# Out:
# sample_data  unifmu-x86_64-unknown-linux-gnu-0.12.0.zip

# %%
# !unzip unifmu-x86_64-unknown-linux-gnu-0.12.0.zip
# Out:
# Archive:  unifmu-x86_64-unknown-linux-gnu-0.12.0.zip
#   inflating: unifmu

# %%
# !ls
# Out:
# sample_data  unifmu  unifmu-x86_64-unknown-linux-gnu-0.12.0.zip

# %% [markdown]
# ## Step-by-Step Implementation
# Now, we have UniFMU installed. We proceed to the same implementation as if it was on a local machine.

# %% [markdown]
# 1. Creation of the FMUs with UniFMU. This creates the Python templates. We'll use the existing FMUs [plant](https://github.com/INTO-CPS-Association/example-incubator-fmi3/tree/main/plant), [controller](https://github.com/INTO-CPS-Association/example-incubator-fmi3/tree/main/controller), and [supervisor](https://github.com/INTO-CPS-Association/example-incubator-fmi3/tree/main/supervisor), which already contain the worked-out logic for the example; feel free to update it as needed.

# %%
# !chmod +x unifmu

# %%
# !./unifmu --help
# Out:
# Implement Functional Mock-up units (FMUs) in various source languages.
#
# * Source:   https://github.com/INTO-CPS-Association/unifmu
# * Examples: https://github.com/INTO-CPS-Association/unifmu_examples
#
# Usage: unifmu <COMMAND>
#
# Commands:
#   generate              Create a new FMU using the specified source language
#   generate-distributed  Generates a pair of FMU/private folder for distributed co-simulation, where the FMU works as the proxy and the folder as the model
#   help                  Print this message or the help of the given subcommand(s)
#
# Options:
#   -h, --help     Print help
#   -V, --version  Print version

# %%
# !./unifmu generate python supervisor fmi3
# !./unifmu generate python controller fmi3
# !./unifmu generate python plant fmi3
# Out:
# [INFO ] Generating FMU version `FMI3` for language 'Python' with tmpdir "/tmp/.tmpff76L5" and final output path "supervisor"
# [INFO ] copying resource "auto_generated/binaries/x86_64-darwin/unifmu.dylib" to "/tmp/.tmpff76L5/binaries/x86_64-darwin/unifmu.dylib"
# [INFO ] copying resource "auto_generated/binaries/x86_64-linux/unifmu.so" to "/tmp/.tmpff76L5/binaries/x86_64-linux/unifmu.so"
# [INFO ] copying resource "auto_generated/binaries/x86_64-windows/unifmu.dll" to "/tmp/.tmpff76L5/binaries/x86_64-windows/unifmu.dll"
# [INFO ] copying resource "python/requirements.txt" to "/tmp/.tmpff76L5/resources/requirements.txt"
# [INFO ] copying resource "python/fmi3/backend.py" to "/tmp/.tmpff76L5/resources/backend.py"
# [INFO ] copying resource "python/fmi3/model.py" to "/tmp/.tmpff76L5/resources/model.py"
# [INFO ] copying resource "auto_generated/fmi3_messages_pb2.py" to "/tmp/.tmpff76L5/resources/schemas/fmi3_messages_pb2.py"
# [INFO ] copying resource "auto_generated/unifmu_handshake_pb2.py" to "/tmp/.tmpff76L5/resources/schemas/unifmu_handshake_pb2.py"
# [INFO ] copying resource "python/launch.toml" to "/tmp/.tmpff76L5/resources/launch.toml"
# [INFO ] copying resource "python/README.md" to "/tmp/.tmpff76L5/resources/README.md"
# [INFO ] copying temporary dir from "/tmp/.tmpff76L5" to output "supervisor"
# [INFO ] the FMU was generated successfully
# [INFO ] Generating FMU version `FMI3` for language 'Python' with tmpdir "/tmp/.tmpApof2O" and final output path "controller"
# [INFO ] copying resource "auto_generated/binaries/x86_64-darwin/unifmu.dylib" to "/tmp/.tmpApof2O/binaries/x86_64-darwin/unifmu.dylib"
# [INFO ] copying resource "auto_generated/binaries/x86_64-linux/unifmu.so" to "/tmp/.tmpApof2O/binaries/x86_64-linux/unifmu.so"
# [INFO ] copying resource "auto_generated/binaries/x86_64-windows/unifmu.dll" to "/tmp/.tmpApof2O/binaries/x86_64-windows/unifmu.dll"
# [INFO ] copying resource "python/requirements.txt" to "/tmp/.tmpApof2O/resources/requirements.txt"
# [INFO ] copying resource "python/fmi3/backend.py" to "/tmp/.tmpApof2O/resources/backend.py"
# [INFO ] copying resource "python/fmi3/model.py" to "/tmp/.tmpApof2O/resources/model.py"
# [INFO ] copying resource "auto_generated/fmi3_messages_pb2.py" to "/tmp/.tmpApof2O/resources/schemas/fmi3_messages_pb2.py"
# [INFO ] copying resource "auto_generated/unifmu_handshake_pb2.py" to "/tmp/.tmpApof2O/resources/schemas/unifmu_handshake_pb2.py"
# [INFO ] copying resource "python/launch.toml" to "/tmp/.tmpApof2O/resources/launch.toml"
# [INFO ] copying resource "python/README.md" to "/tmp/.tmpApof2O/resources/README.md"
# [INFO ] copying temporary dir from "/tmp/.tmpApof2O" to output "controller"
# [INFO ] the FMU was generated successfully
# [INFO ] Generating FMU version `FMI3` for language 'Python' with tmpdir "/tmp/.tmpeCiO4Z" and final output path "plant"
# [INFO ] copying resource "auto_generated/binaries/x86_64-darwin/unifmu.dylib" to "/tmp/.tmpeCiO4Z/binaries/x86_64-darwin/unifmu.dylib"
# [INFO ] copying resource "auto_generated/binaries/x86_64-linux/unifmu.so" to "/tmp/.tmpeCiO4Z/binaries/x86_64-linux/unifmu.so"
# [INFO ] copying resource "auto_generated/binaries/x86_64-windows/unifmu.dll" to "/tmp/.tmpeCiO4Z/binaries/x86_64-windows/unifmu.dll"
# [INFO ] copying resource "python/requirements.txt" to "/tmp/.tmpeCiO4Z/resources/requirements.txt"
# [INFO ] copying resource "python/fmi3/backend.py" to "/tmp/.tmpeCiO4Z/resources/backend.py"
# [INFO ] copying resource "python/fmi3/model.py" to "/tmp/.tmpeCiO4Z/resources/model.py"
# [INFO ] copying resource "auto_generated/fmi3_messages_pb2.py" to "/tmp/.tmpeCiO4Z/resources/schemas/fmi3_messages_pb2.py"
# [INFO ] copying resource "auto_generated/unifmu_handshake_pb2.py" to "/tmp/.tmpeCiO4Z/resources/schemas/unifmu_handshake_pb2.py"
# [INFO ] copying resource "python/launch.toml" to "/tmp/.tmpeCiO4Z/resources/launch.toml"
# [INFO ] copying resource "python/README.md" to "/tmp/.tmpeCiO4Z/resources/README.md"
# [INFO ] copying temporary dir from "/tmp/.tmpeCiO4Z" to output "plant"
# [INFO ] the FMU was generated successfully

# %%
# !ls
# Out:
# controller  sample_data  unifmu
# plant	    supervisor	 unifmu-x86_64-unknown-linux-gnu-0.12.0.zip

# %% [markdown]
# Now, we have all the FMU templates (empty) generated with UniFMU. We'll download the worked-out FMUs.

# %%
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/plant.fmu
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/supervisor.fmu
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/controller.fmu
# Out:
# --2025-07-18 09:28:03--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/plant.fmu
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/plant.fmu [following]
# --2025-07-18 09:28:04--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/plant.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5712982 (5.4M) [application/octet-stream]
# Saving to: ‘plant.fmu’
#
# plant.fmu           100%[===================>]   5.45M  --.-KB/s    in 0.02s
#
# 2025-07-18 09:28:04 (245 MB/s) - ‘plant.fmu’ saved [5712982/5712982]
#
# --2025-07-18 09:28:04--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/supervisor.fmu
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/supervisor.fmu [following]
# --2025-07-18 09:28:04--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/supervisor.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5713794 (5.4M) [application/octet-stream]
# Saving to: ‘supervisor.fmu’
#
# supervisor.fmu      100%[===================>]   5.45M  --.-KB/s    in 0.02s
#
# 2025-07-18 09:28:04 (304 MB/s) - ‘supervisor.fmu’ saved [5713794/5713794]
#
# --2025-07-18 09:28:04--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/controller.fmu
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/controller.fmu [following]
# --2025-07-18 09:28:04--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/controller.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5713038 (5.4M) [application/octet-stream]
# Saving to: ‘controller.fmu’
#
# controller.fmu      100%[===================>]   5.45M  --.-KB/s    in 0.02s
#
# 2025-07-18 09:28:04 (267 MB/s) - ‘controller.fmu’ saved [5713038/5713038]

# %%
# !ls
# Out:
# controller	plant.fmu    supervisor.fmu
# controller.fmu	sample_data  unifmu
# plant		supervisor   unifmu-x86_64-unknown-linux-gnu-0.12.0.zip

# %% [markdown]
# Now, we'll download the remaining files and create the directories to run the co-simulation

# %%
# !wget https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/co-simulation_scenario.py # Downloads the co-simulation algorithm
# !wget https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/wrap_fmus.sh # Downloads the script to wrap the directories as FMUs (zip)
# !chmod +x wrap_fmus.sh # Gives execution permission to the wrap_fmus.sh script
# !mkdir data # To store the results of the co-simulation
# !mkdir plots # To plot the data saved
!(cd plots && wget https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/plots/plot.py && cd ..) # Downloads the plotting script
# !mkdir fmpy
!(cd fmpy && wget https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/fmpy/fmi3.py & cd ..) # Downloads the extended FMPy FMI3 API
# !ls
# Out:
# --2025-07-18 09:21:40--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/co-simulation_scenario.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17021 (17K) [text/plain]
# Saving to: ‘co-simulation_scenario.py’
#
# co-simulation_scena 100%[===================>]  16.62K  --.-KB/s    in 0s
#
# 2025-07-18 09:21:40 (98.6 MB/s) - ‘co-simulation_scenario.py’ saved [17021/17021]
#
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘plots’: File exists
# --2025-07-18 09:21:40--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/plots/plot.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3200 (3.1K) [text/plain]
# Saving to: ‘plot.py’
#
# plot.py             100%[===================>]   3.12K  --.-KB/s    in 0s
#
# 2025-07-18 09:21:40 (57.3 MB/s) - ‘plot.py’ saved [3200/3200]
#
# mkdir: cannot create directory ‘fmpy’: File exists
# --2025-07-18 09:21:41--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/fmpy/fmi3.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46718 (46K) [text/plain]
# Saving to: ‘fmi3.py’
#
# fmi3.py             100%[===================>]  45.62K  --.-KB/s    in 0.001s
#
# 2025-07-18 09:21:41 (38.5 MB/s) - ‘fmi3.py’ saved [46718/46718]
#
# controller		   plots
# controller.fmu		   sample_data
# co-simulation_scenario.py  supervisor
# data			   supervisor.fmu
# fmpy			   unifmu
# plant			   unifmu-x86_64-unknown-linux-gnu-0.12.0.zip
# plant.fmu

# %% [markdown]
# Now, we need to update the original FMPy FMI3 script with our extended version to support clock-related functions

# %%
# !pip3 show fmpy # To check where the file is
# Out:
# Name: FMPy
# Version: 0.3.25
# Summary: Simulate Functional Mock-up Units (FMUs) in Python
# Home-page:
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: attrs, jinja2, lark, lxml, msgpack, nbformat, numpy
# Required-by:

# %%
# !ls /usr/local/lib/python3.11/dist-packages/fmpy/
# Out:
# c-code		 fmi3.py	       __pycache__    templates
# command_line.py  fmucontainer	       remoting       util.py
# cross_check	 gui		       schema	      validation.py
# cswrapper	 __init__.py	       simulation.py  webapp
# examples	 logging	       ssp
# fmi1.py		 __main__.py	       sundials
# fmi2.py		 model_description.py  template.py

# %%
# !cp fmpy/fmi3.py /usr/local/lib/python3.11/dist-packages/fmpy/ # Copies the extended file to the site-packages installed

# %% [markdown]
# Now we can run the co-simulation with the FMUs and the extended FMPy fmi3 library

# %%
# !python3 co-simulation_scenario.py
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 140.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  22.983154296875
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.119598388671875
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 141.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  22.993942260742188
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.13746452331543
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 141.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.00473976135254
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.155311584472656
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 142.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.015548706054688
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.173141479492188
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 142.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.0263671875
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.19095230102539
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 143.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.037195205688477
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.2087459564209
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 143.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.04803466796875
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.226520538330078
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 144.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.058881759643555
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.244279861450195
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 144.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.06974220275879
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.262020111083984
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 145.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.080610275268555
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.279743194580078
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 145.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.091487884521484
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.297449111938477
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 146.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.102375030517578
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.31513786315918
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 146.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.113271713256836
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.332809448242188
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 147.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.12417984008789
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.3504638671875
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 147.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.135095596313477
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.368101119995117
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 148.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.146020889282227
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.385719299316406
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 148.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.156953811645508
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.403322219848633
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 149.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.167898178100586
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.420909881591797
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.02312660217285
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 149.5
# INFO:/content/co-simulation_scenario.py:Controller time event or supervisor event
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.178850173950195
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.438478469848633
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 150.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.18981170654297
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.456029891967773
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 150.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.200780868530273
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.47356605529785
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 151.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.211759567260742
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.491085052490234
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 151.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.222747802734375
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.508586883544922
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 152.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.23374366760254
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.526073455810547
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 152.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.244747161865234
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.543542861938477
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 153.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.255760192871094
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.56099510192871
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 153.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.266780853271484
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.578432083129883
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 154.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.277809143066406
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.59585189819336
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 154.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.288846969604492
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.613256454467773
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 155.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.29989242553711
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.630643844604492
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 155.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.310945510864258
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.64801597595215
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 156.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.322006225585938
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.66537094116211
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 156.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.33307456970215
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.682710647583008
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 157.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.34415054321289
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.700035095214844
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 157.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.355234146118164
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.717342376708984
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 158.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.36632537841797
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.734634399414062
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 158.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.377424240112305
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.751911163330078
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 159.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.388530731201172
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.7691707611084
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 159.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.399642944335938
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.78641700744629
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 160.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.410764694213867
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.803646087646484
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 160.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.421892166137695
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.820859909057617
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 161.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.433025360107422
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.838058471679688
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 161.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.444168090820312
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.855241775512695
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 162.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.4553165435791
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.87240982055664
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 162.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.46647071838379
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.889562606811523
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 163.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.477632522583008
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.906700134277344
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 163.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.488801956176758
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.92382049560547
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 164.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.499977111816406
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.940927505493164
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 164.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.511157989501953
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.95802116394043
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 165.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.52234649658203
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.97509765625
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 165.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.533540725708008
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  27.992158889770508
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 166.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.544740676879883
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.009206771850586
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 166.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.55594825744629
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.0262393951416
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 167.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.567161560058594
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.043256759643555
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 167.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.578380584716797
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.060258865356445
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 168.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.5896053314209
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.077247619628906
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 168.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.6008358001709
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.094221115112305
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 169.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.612071990966797
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.11117935180664
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 169.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.623315811157227
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.128124237060547
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 170.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.634563446044922
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.14505386352539
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 170.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.645816802978516
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.161968231201172
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 171.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.657075881958008
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.178869247436523
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 171.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.6683406829834
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.195756912231445
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 172.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.679611206054688
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.212629318237305
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 172.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.690887451171875
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.2294864654541
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 173.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.702167510986328
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.24633026123047
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 173.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.713455200195312
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.263160705566406
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 174.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.72474479675293
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.27997589111328
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 174.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.736042022705078
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.296777725219727
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 175.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.747343063354492
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.313566207885742
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 175.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.758649826049805
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.330341339111328
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 176.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.769960403442383
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.34710121154785
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 176.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.78127670288086
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.363845825195312
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 177.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.792598724365234
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.380578994750977
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 177.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.803922653198242
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.397296905517578
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 178.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.81525421142578
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.414003372192383
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 178.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.826587677001953
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.430694580078125
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 179.0
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.837926864624023
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.447372436523438
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 179.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.849271774291992
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.464035034179688
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 180.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.860620498657227
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.48068618774414
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 180.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.871973037719727
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.497323989868164
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 181.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.883329391479492
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.513948440551758
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 181.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.894689559936523
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.53055763244629
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 182.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.906055450439453
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.547155380249023
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 182.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.91742515563965
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.563739776611328
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 183.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.928796768188477
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.58030891418457
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 183.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.940174102783203
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.596866607666016
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 184.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.951555252075195
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.61341094970703
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 184.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.962940216064453
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.629941940307617
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 185.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.974328994750977
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.646459579467773
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 185.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.985721588134766
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.662965774536133
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 186.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  23.99711799621582
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.67945671081543
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 186.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  24.00851821899414
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.69593620300293
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 187.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  24.019922256469727
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.71240234375
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 187.5
# INFO:/content/co-simulation_scenario.py:Plant.T :  24.031328201293945
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  28.728857040405273
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.072683334350586
# ...
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 485.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.542659759521484
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  36.99717330932617
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 485.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.552541732788086
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.0091552734375
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 486.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.56241798400879
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.0211296081543
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 486.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.572290420532227
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.03310012817383
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 487.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.5821590423584
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.04506301879883
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 487.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.592023849487305
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.05702209472656
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 488.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.601884841918945
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.068973541259766
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 488.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.61174201965332
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.0809211730957
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 489.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.621593475341797
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.092864990234375
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 489.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.631441116333008
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.104801177978516
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 490.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.641286849975586
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.11673355102539
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 490.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.651126861572266
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.128662109375
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 491.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.66096305847168
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.14058303833008
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 491.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.670793533325195
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.15250015258789
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 492.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.680622100830078
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.16440963745117
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 492.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.690444946289062
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.17631530761719
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 493.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.700265884399414
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.18821716308594
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 493.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.710081100463867
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.200111389160156
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 494.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.719892501831055
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.21200180053711
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 494.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.729700088500977
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.22388458251953
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 495.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.739503860473633
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.23576354980469
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 495.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.74930191040039
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.24763870239258
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 496.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.759098052978516
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.25950622558594
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 496.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.768888473510742
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.27136993408203
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 497.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.778675079345703
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.28322982788086
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 497.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.7884578704834
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.295082092285156
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 498.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.798236846923828
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.30693054199219
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 498.5
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.808012008666992
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.31877136230469
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 499.0
# INFO:/content/co-simulation_scenario.py:Controller time event ONLY
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.81778335571289
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.33060836791992
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/content/co-simulation_scenario.py:Doing a step of size 0.5 at time 499.5
# INFO:/content/co-simulation_scenario.py:Controller time event or supervisor event
# INFO:/content/co-simulation_scenario.py:Plant.T :  30.82754898071289
# INFO:/content/co-simulation_scenario.py:Plant.T_heater :  37.34244155883789
# INFO:/content/co-simulation_scenario.py:Controller.heater_ctrl :  True
# INFO:/content/co-simulation_scenario.py:Supervisor.temperature_desired :  35.0
# INFO:/content/co-simulation_scenario.py:Supervisor.heating_time :  20.09285545349121
# INFO:/tmp/tmpwd44plb6/resources/backend.py:Fmi3FreeInstance received, shutting down
# INFO:/tmp/tmpirmi3ow_/resources/backend.py:Fmi3FreeInstance received, shutting down

# %% [markdown]
# Now we can plot the data

# %%
# !python3 plots/plot.py data/simulation_data.csv --save
# Out:
# Figure(1200x1200)
# Plot saved in /content/plots

# %% [markdown]
# The plots are now saved in the folder `plots`.

# %% [markdown]
# ## Updating the logic

# %% [markdown]
# I'll work based on the worked-out FMUs. Feel free to work on either the empty templates or the worked-out FMUs.

# %%
# Removes the folders and FMUs created with UniFMU so far
# !rm -r controller
# !rm -r plant
# !rm -r supervisor
# !rm controller.fmu
# !rm plant.fmu
# !rm supervisor.fmu

# %%
# Downloads again the worked-out FMUs
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/plant.fmu
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/supervisor.fmu
# !wget https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/controller.fmu
# Out:
# --2025-07-18 10:19:41--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/plant.fmu
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/plant.fmu [following]
# --2025-07-18 10:19:42--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/plant.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5293338 (5.0M) [application/octet-stream]
# Saving to: ‘plant.fmu’
#
# plant.fmu           100%[===================>]   5.05M  --.-KB/s    in 0.02s
#
# 2025-07-18 10:19:42 (301 MB/s) - ‘plant.fmu’ saved [5293338/5293338]
#
# --2025-07-18 10:19:42--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/supervisor.fmu
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/supervisor.fmu [following]
# --2025-07-18 10:19:42--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/supervisor.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5294120 (5.0M) [application/octet-stream]
# Saving to: ‘supervisor.fmu’
#
# supervisor.fmu      100%[===================>]   5.05M  --.-KB/s    in 0.02s
#
# 2025-07-18 10:19:42 (314 MB/s) - ‘supervisor.fmu’ saved [5294120/5294120]
#
# --2025-07-18 10:19:42--  https://github.com/INTO-CPS-Association/example-incubator-fmi3/raw/refs/heads/main/original_FMUs/controller.fmu
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/controller.fmu [following]
# --2025-07-18 10:19:42--  https://raw.githubusercontent.com/INTO-CPS-Association/example-incubator-fmi3/refs/heads/main/original_FMUs/controller.fmu
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5293394 (5.0M) [application/octet-stream]
# Saving to: ‘controller.fmu’
#
# controller.fmu      100%[===================>]   5.05M  --.-KB/s    in 0.02s
#
# 2025-07-18 10:19:42 (283 MB/s) - ‘controller.fmu’ saved [5293394/5293394]

# %%
# Unzips the worked-out FMUs
# !unzip plant.fmu -d plant
# !unzip supervisor.fmu -d supervisor
# !unzip controller.fmu -d controller
# Out:
# Archive:  plant.fmu
#    creating: plant/binaries/
#    creating: plant/binaries/x86_64-linux/
#   inflating: plant/binaries/x86_64-linux/unifmu.so
#    creating: plant/binaries/x86_64-darwin/
#   inflating: plant/binaries/x86_64-darwin/unifmu.dylib
#    creating: plant/binaries/x86_64-windows/
#   inflating: plant/binaries/x86_64-windows/unifmu.dll
#   inflating: plant/modelDescription.xml
#    creating: plant/resources/
#    creating: plant/resources/schemas/
#   inflating: plant/resources/schemas/fmi3_messages_pb2.py
#   inflating: plant/resources/schemas/unifmu_handshake_pb2.py
#   inflating: plant/resources/backend.py
#   inflating: plant/resources/requirements.txt
#   inflating: plant/resources/README.md
#   inflating: plant/resources/launch.toml
#   inflating: plant/resources/model.py
# Archive:  supervisor.fmu
#    creating: supervisor/binaries/
#    creating: supervisor/binaries/x86_64-linux/
#   inflating: supervisor/binaries/x86_64-linux/unifmu.so
#    creating: supervisor/binaries/x86_64-darwin/
#   inflating: supervisor/binaries/x86_64-darwin/unifmu.dylib
#    creating: supervisor/binaries/x86_64-windows/
#   inflating: supervisor/binaries/x86_64-windows/unifmu.dll
#   inflating: supervisor/modelDescription.xml
#    creating: supervisor/resources/
#    creating: supervisor/resources/schemas/
#   inflating: supervisor/resources/schemas/fmi3_messages_pb2.py
#   inflating: supervisor/resources/schemas/unifmu_handshake_pb2.py
#   inflating: supervisor/resources/backend.py
#   inflating: supervisor/resources/requirements.txt
#   inflating: supervisor/resources/README.md
#   inflating: supervisor/resources/launch.toml
#   inflating: supervisor/resources/model.py
# Archive:  controller.fmu
#    creating: controller/binaries/
#    creating: controller/binaries/x86_64-linux/
#   inflating: controller/binaries/x86_64-linux/unifmu.so
#    creating: controller/binaries/x86_64-darwin/
#   inflating: controller/binaries/x86_64-darwin/unifmu.dylib
#    creating: controller/binaries/x86_64-windows/
#   inflating: controller/binaries/x86_64-windows/unifmu.dll
#   inflating: controller/modelDescription.xml
#    creating: controller/resources/
#    creating: controller/resources/schemas/
#   inflating: controller/resources/schemas/fmi3_messages_pb2.py
#   inflating: controller/resources/schemas/unifmu_handshake_pb2.py
#   inflating: controller/resources/backend.py
#   inflating: controller/resources/requirements.txt
#   inflating: controller/resources/README.md
#   inflating: controller/resources/launch.toml
#   inflating: controller/resources/model.py

# %% [markdown]
# Now we can explore the contents of the FMUs, within the `resources/model.py` script of each FMU.
# Double-click on the Supervisor's `model.py` and go to the `fmi3UpdateDiscreteStates` function.
#
# Currently, the logic randomly updates the `heating_time` by a +-0.05 of the current value every time the condition given is satisfied.
# Similarly, the attribute `temperature_desired` that is passed to the controller FMU is randomly updated by a +-1.0 of the current setpoint.
#
# Update these two behaviors and save the changes.
#
# Now, we need to use the `wrap_fmus.sh` script to zip the models.

# %%
# !./wrap_fmus.sh

# %% [markdown]
# And finally, execute the `co-simulation_scenario.py` script.
# Feel free to update the co-simulation parameters (*line 14*) and initial values of the FMUs in initialization mode (*line 149*).
# This algorithm will compute the co-simulation with your changes.

# %%
# !python3 co-simulation_scenario.py

# %% [markdown]
# Plot the results

# %%
# !python3 plots/plot.py data/simulation_data.csv --save

# %% [markdown]
# The plots are now saved in the folder `plots`.

# %% [markdown]
# ## End of tutorial
# **Q&A**
